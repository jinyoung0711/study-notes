# %% [markdown]
# # 1. BASIC SINGLE LINE PLOT

# %%
# The plot method on Pandas Series and DataFrames is just a simple wrapper around plt.plot():

import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
# Use Pandas read_csv to read crypto daily prices (BTC, ETH, and LTC)

investment_df = pd.read_csv('crypto_daily_prices.csv')
investment_df
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %%
# Use matplotlib on the Pandas DataFrame to plot the data

investment_df.plot(x='Date', y='BTC-USD Price', label='Bitcoin Price', linewidth=3, figsize=(14, 6))

# label의 위치 수정
plt.ylabel('Price [$]')
plt.xlabel('Date')
plt.title('My First Data Visualization Code!')
plt.legend(loc='lower right')
plt.grid()

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **Plot similar kind of graph for Ethereum instead**
# - **Change the line color to red**

# %%
investment_df.plot(x='Date', y='ETH-USD Price', label='Ethereum Price', linewidth=2, figsize=(14, 6), color='r')
plt.xlabel('Date')
plt.ylabel('Price [$]')
plt.title('MINI CHALLENGE #1')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # 2. DOWNLOAD DATA DIRECTLY FROM YAHOO FINANCE

# %%
# yfinance library offers an easy, reliable and Pythonic way to download market data from Yahoo finance
! pip install yfinance
import yfinance as yf

# %%
# List all Ticker Symbols in the list below, let's start with one!

investments_list = ['BTC-USD']

# Specify the start and end dates

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 5, 16)

# Download the data from Yahoo Finance, make sure to reset index!

df = yf.download(investments_list, start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2014-09-17    457.334015    468.174011    452.421997    465.864014
# 2014-09-18    424.440002    456.859985    413.104004    456.859985
# 2014-09-19    394.795990    427.834991    384.532013    424.102997
# 2014-09-20    408.903992    423.295990    389.882996    394.673004
# 2014-09-21    398.821014    412.425995    393.181000    408.084991
# ...                  ...           ...           ...           ...
# 2021-05-11  56704.574219  56872.542969  54608.652344  55847.242188
# 2021-05-12  49150.535156  57939.363281  49150.535156  56714.531250
# 2021-05-13  49716.191406  51330.843750  46980.019531  49735.433594
# 2021-05-14  49880.535156  51438.117188  48868.578125  49682.980469
# 2021-05-15  46760.187500  50639.664062  46664.140625  49855.496094
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2014-09-17     21056800
# ...

# %%
# Reset index as follows:

df.reset_index(inplace=True)
df
# Out:
# Price        Date         Close          High           Low          Open  \
# Ticker                  BTC-USD       BTC-USD       BTC-USD       BTC-USD
# 0      2014-09-17    457.334015    468.174011    452.421997    465.864014
# 1      2014-09-18    424.440002    456.859985    413.104004    456.859985
# 2      2014-09-19    394.795990    427.834991    384.532013    424.102997
# 3      2014-09-20    408.903992    423.295990    389.882996    394.673004
# 4      2014-09-21    398.821014    412.425995    393.181000    408.084991
# ...           ...           ...           ...           ...           ...
# 2428   2021-05-11  56704.574219  56872.542969  54608.652344  55847.242188
# 2429   2021-05-12  49150.535156  57939.363281  49150.535156  56714.531250
# 2430   2021-05-13  49716.191406  51330.843750  46980.019531  49735.433594
# 2431   2021-05-14  49880.535156  51438.117188  48868.578125  49682.980469
# 2432   2021-05-15  46760.187500  50639.664062  46664.140625  49855.496094
#
# ...

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Use Yahoo Finance to download Ethereum data instead of BTC**
# - **USe Yahoo Finance to download BTC, ETH, and LTC**

# %%
# ETH data

investments_list = ['ETH-USD']

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 5, 16)

eth_df = yf.download(investments_list, start=start, end=end)
eth_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open       Volume
# Ticker          ETH-USD      ETH-USD      ETH-USD      ETH-USD      ETH-USD
# Date
# 2017-11-09   320.884003   329.451996   307.056000   308.644989    893249984
# 2017-11-10   299.252991   324.717987   294.541992   320.670990    885985984
# 2017-11-11   314.681000   319.453003   298.191986   298.585999    842300992
# 2017-11-12   307.907990   319.153015   298.513000   314.690002   1613479936
# 2017-11-13   316.716003   328.415009   307.024994   307.024994   1041889984
# ...                 ...          ...          ...          ...          ...
# 2021-05-11  4168.701172  4178.208984  3783.889404  3948.271973  52679737865
# 2021-05-12  3785.848633  4362.350586  3785.848633  4174.635742  69023382175
# 2021-05-13  3715.148438  4032.563477  3549.407227  3828.918457  78398214539
# ...

# %%
# BTC, ETH and LTC

investments_list = ['BTC-USD','ETH-USD', 'LTC-USD']

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 5, 16)

finance_df = yf.download(investments_list, start=start, end=end)
finance_df
# Out:
# [*********************100%***********************]  3 of 3 completed
# Price              Close                                   High               \
# Ticker           BTC-USD      ETH-USD     LTC-USD       BTC-USD      ETH-USD
# Date
# 2014-09-17    457.334015          NaN    5.058550    468.174011          NaN
# 2014-09-18    424.440002          NaN    4.685230    456.859985          NaN
# 2014-09-19    394.795990          NaN    4.327770    427.834991          NaN
# 2014-09-20    408.903992          NaN    4.286440    423.295990          NaN
# 2014-09-21    398.821014          NaN    4.245920    412.425995          NaN
# ...                  ...          ...         ...           ...          ...
# 2021-05-11  56704.574219  4168.701172  377.388794  56872.542969  4178.208984
# 2021-05-12  49150.535156  3785.848633  303.084869  57939.363281  4362.350586
# 2021-05-13  49716.191406  3715.148438  316.909332  51330.843750  4032.563477
# ...

# %% [markdown]
# # 3. MULTIPLE PLOTS

# %%
# Use Pandas read_csv to read crypto daily prices (BTC, ETH, and LTC)

investment_df = pd.read_csv('crypto_daily_prices.csv')
investment_df
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %%
investment_df.plot(x='Date', y=['BTC-USD Price', 'ETH-USD Price'], linewidth=2, figsize=(14,6))
plt.ylabel('Price')
plt.title('Crypto Prices')
plt.grid()

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Add Litecoin (LTC) to the list and plot similar kind of graph showing all three crypto currencies**

# %%
investment_df.plot(x='Date', y=['BTC-USD Price', 'ETH-USD Price', 'LTC-USD Price'], linewidth=1, figsize=(14,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # 4. SUBPLOTS

# %%
investment_df.plot(x='Date', title='Crypto Prices', subplots=True, grid=True, figsize=(15,10))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Try to set subplots = False and examine the output.**

# %%
investment_df.plot(x='Date', title='Crypto Prices', subplots=False, grid=True, figsize=(15,10))
# Out:
# <Axes: title={'center': 'Crypto Prices'}, xlabel='Date'>

# %% [markdown]
# # 5. SCATTERPLOT

# %%
# Read daily return data using pandas

daily_return_df = pd.read_csv('crypto_daily_returns.csv')
daily_return_df
# Out:
#            Date       BTC       ETH       LTC
# 0     9/17/2014  0.000000  0.000000  0.000000
# 1     9/18/2014 -7.192558       NaN -7.379983
# 2     9/19/2014 -6.984264       NaN -7.629499
# 3     9/20/2014  3.573492       NaN -0.955003
# 4     9/21/2014 -2.465854       NaN -0.945300
# ...         ...       ...       ...       ...
# 2380  3/28/2021 -0.040672 -1.464535  0.107149
# 2381  3/29/2021  3.216138  7.587343  5.105316
# 2382  3/30/2021  2.021625  1.447984  1.135017
# 2383  3/31/2021  0.001936  3.918042  0.415392
# 2384   4/1/2021  0.300374  3.071099  3.348582
#
# [2385 rows x 4 columns]

# %%
# Plot Daily returns of BTC vs. ETH

daily_return_df.plot.scatter('BTC', 'ETH', grid=True, figsize=(12,7))
# Out:
# <Axes: xlabel='BTC', ylabel='ETH'>

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Plot the daily returns of BTC vs. LTC**

# %%
# Plot Daily returns of BTC vs. LTC

daily_return_df.plot.scatter('BTC', 'LTC', grid=True, figsize=(12,7))
# Out:
# <Axes: xlabel='BTC', ylabel='LTC'>

# %% [markdown]
# # 6. PIE CHART

# %%
# Define a dictionary with all crypto allocation in a portfolio
# Note that total summation = 100%

my_dict = {'allocation %': [20, 55, 5, 17, 3]}
my_dict
# Out:
# {'allocation %': [20, 55, 5, 17, 3]}

# %%
crypto_df = pd.DataFrame(data=my_dict, index=['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])
crypto_df
# Out:
#      allocation %
# BTC            20
# ETH            55
# LTC             5
# XRP            17
# ADA             3

# %%
# Use matplotlib to plot a pie chart

crypto_df.plot.pie(y='allocation %', figsize=(8,8))
plt.title('Crypto Portfolio Pie Chart')
# Out:
# Text(0.5, 1.0, 'Crypto Portfolio Pie Chart')

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **Assume that you became bullish on XRP and decided to allocate 60% of your assets in it. You also decided to equally divide the rest of your assets in other coins (BTC, LTC, ADA, and ETH). Change the allocations and plot the pie chart.**
# - **Use 'explode' to increase the separation between XRP and the rest of the portfolio (External Research is Required)**

# %%
my_dict = {'allocation %': [10, 10, 10, 60, 10]}

crypto_df = pd.DataFrame(data=my_dict, index=['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])

crypto_df.plot.pie(y='allocation %')
plt.title('Crypto Portfolio Pie Chart')
# Out:
# Text(0.5, 1.0, 'Crypto Portfolio Pie Chart')

# %%
explode = (0, 0, 0, 0.2, 0)

crypto_df.plot.pie(y='allocation %', explode=explode)
plt.title('Crypto Portfolio Pie Chart with using explode ')
# Out:
# Text(0.5, 1.0, 'Crypto Portfolio Pie Chart with using explode ')

# %% [markdown]
# # 7. HISTOGRAMS

# %%
# A histogram represents data using bars with various heights
# Each bar groups numbers into specific ranges
# Taller bars show that more data falls within that specific range

daily_return_df = pd.read_csv('crypto_daily_returns.csv')
daily_return_df
# Out:
#            Date       BTC       ETH       LTC
# 0     9/17/2014  0.000000  0.000000  0.000000
# 1     9/18/2014 -7.192558       NaN -7.379983
# 2     9/19/2014 -6.984264       NaN -7.629499
# 3     9/20/2014  3.573492       NaN -0.955003
# 4     9/21/2014 -2.465854       NaN -0.945300
# ...         ...       ...       ...       ...
# 2380  3/28/2021 -0.040672 -1.464535  0.107149
# 2381  3/29/2021  3.216138  7.587343  5.105316
# 2382  3/30/2021  2.021625  1.447984  1.135017
# 2383  3/31/2021  0.001936  3.918042  0.415392
# 2384   4/1/2021  0.300374  3.071099  3.348582
#
# [2385 rows x 4 columns]

# %%
# Find the statistical value of the distribution

mu = daily_return_df['BTC'].mean()
sigma = daily_return_df['BTC'].std()

# Visualization

plt.figure(figsize=(12, 6))
daily_return_df['BTC'].plot.hist(bins=50, alpha=0.5)

plt.grid()
plt.title('Histogram: mu=' + str(mu) + ', sigma=' + str(sigma))
# Out:
# Text(0.5, 1.0, 'Histogram: mu=0.28035901623060794, sigma=3.8873383909050667')

# %% [markdown]
# **MINI CHALLENGE #7:**
# - **Plot the histogram for ETH returns using 30 bins with red color**

# %%
# Find the statistical value of the distribution

mu = daily_return_df['ETH'].mean()
sigma = daily_return_df['ETH'].std()

# Visualization

plt.figure(figsize=(12, 6))
daily_return_df['ETH'].plot.hist(bins=30, alpha=0.5, color='r')

plt.grid()
plt.title('Histogram: mu=' + str(mu) + ', sigma=' + str(sigma))
# Out:
# Text(0.5, 1.0, 'Histogram: mu=0.5387388971494419, sigma=6.4719718121628755')

# %% [markdown]
# **FINAL BREAKOUT ROOM CHALLENGE:**
# - **Use the stock_daily_prices.csv data that is included in the course/workshop package, plot a graph containing all prices of AAPL, sp500 and GOOG on one graph**
# - **Plot a subplot containing all prices of AAPL, sp500 and GOOG in individual graphs**
# - **Add legends indicating S&P500, AAPL and GOOG**
# - **Place the legend in the "upper center" location**

# %%
import matplotlib.pyplot as plot
import pandas as pd

stock_df = pd.read_csv('stock_daily_prices.csv')
stock_df
# Out:
#             Date        AAPL          BA          T        MGM         AMZN  \
# 0     2012-01-12   60.198570   75.510002  30.120001  12.130000   175.929993
# 1     2012-01-13   59.972858   74.599998  30.070000  12.350000   178.419998
# 2     2012-01-17   60.671429   75.239998  30.250000  12.250000   181.660004
# 3     2012-01-18   61.301430   75.059998  30.330000  12.730000   189.440002
# 4     2012-01-19   61.107143   75.559998  30.420000  12.800000   194.449997
# ...          ...         ...         ...        ...        ...          ...
# 2154  2020-08-05  440.250000  174.279999  29.850000  16.719999  3205.030029
# 2155  2020-08-06  455.609985  172.199997  29.840000  18.459999  3225.000000
# 2156  2020-08-07  444.450012  170.020004  30.020000  19.030001  3167.459961
# 2157  2020-08-10  450.910004  179.410004  30.200001  21.650000  3148.159912
# 2158  2020-08-11  437.500000  180.130005  30.200001  21.500000  3080.669922
#
#              IBM         TSLA         GOOG        sp500
# ...

# %%
#1 Use the stock_daily_prices.csv data that is included in the course/workshop package, plot a graph containing all prices of AAPL, sp500 and GOOG on one graph

stock_df.plot(x='Date', y=['AAPL', 'sp500', 'GOOG'], linewidth=1, figsize=(12, 6))
plt.title('FINAL BREAKOUT ROOM CHALLENGE 1')
plt.grid()
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py'>

# %%
#2 Plot a subplot containing all prices of AAPL, sp500 and GOOG in individual graphs

stock_df.plot(x='Date', y=['AAPL', 'sp500', 'GOOG'], subplots=True, linewidth=1, figsize=(12, 6))
plt.title('FINAL BREAKOUT ROOM CHALLENGE 2')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-530c5ce1e5f6> in <cell line: 0>()
#       1 #2 Plot a subplot containing all prices of AAPL, sp500 and GOOG in individual graphs
#       2
# ----> 3 fig, axes = stock_df.plot(x='Date', y=['AAPL', 'sp500', 'GOOG'], subplots=True, linewidth=1, figsize=(12, 6))
#       4
#       5 # 모든 서브플롯에 grid 적용
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # MINI CHALLENGES SOLUTIONS

# %% [markdown]
# **MINI CHALLENGE #1 SOLUTION:**
# - **Plot similar kind of graph for Ethereum instead**
# - **Change the color line to red**

# %%
investments_df.plot(x = 'Date', y = 'ETH-USD Price', label = 'ETH Price', linewidth = 3, color = 'r', figsize = (14, 6));
plt.ylabel('Price [$]')
plt.title('Ethereum Price')
plt.legend(loc = "upper right")
plt.grid()

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **Use Yahoo Finance to download Ethereum data instead of BTC**
# - **USe Yahoo Finance to download BTC, ETH, and LTC**

# %%
# yfinance library offers an easy, reliable and Pythonic way to download market data from Yahoo finance
# !pip install yfinance
import yfinance as yf

# %%
# List all Ticker Symbols in the list below
investments_list = ["ETH-USD"]

# Specify the start and end dates
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 4, 16)

# Download the data from Yahoo Finance, make sure to reset index!
df = yf.download(investments_list, start = start, end = end)
df.reset_index(inplace = True)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date         Open  ...    Adj Close       Volume
# 0    2015-08-07     2.831620  ...     2.772120       164329
# 1    2015-08-08     2.793760  ...     0.753325       674188
# 2    2015-08-09     0.706136  ...     0.701897       532170
# 3    2015-08-10     0.713989  ...     0.708448       405283
# 4    2015-08-11     0.708087  ...     1.067860      1463100
# ...         ...          ...  ...          ...          ...
# 2071 2021-04-12  2157.361816  ...  2139.353271  21727936609
# 2072 2021-04-13  2139.364258  ...  2299.187744  29456642939
# 2073 2021-04-14  2299.347900  ...  2435.104980  35592822986
# 2074 2021-04-15  2436.034668  ...  2519.116211  32325606817
# 2075 2021-04-16  2516.601807  ...  2431.946533  36196928256
#
# [2076 rows x 7 columns]

# %%
# List all Ticker Symbols in the list below
investments_list = ['BTC-USD', 'ETH-USD', 'LTC-USD']

# Specify the start and end dates
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 4, 16)

# Download the data from Yahoo Finance, make sure to reset index!
df = yf.download(investments_list, start = start, end = end)
df.reset_index(inplace = True)
df
# Out:
# [*********************100%***********************]  3 of 3 completed
#            Date     Adj Close  ...        Volume
#                       BTC-USD  ...       ETH-USD      LTC-USD
# 0    2014-09-17    457.334015  ...           NaN      3071840
# 1    2014-09-18    424.440002  ...           NaN      4569260
# 2    2014-09-19    394.795990  ...           NaN      3917450
# 3    2014-09-20    408.903992  ...           NaN      5490660
# 4    2014-09-21    398.821014  ...           NaN      2931220
# ...         ...           ...  ...           ...          ...
# 2395 2021-04-12  59893.453125  ...  2.172794e+10   5220366581
# 2396 2021-04-13  63503.457031  ...  2.945664e+10   6908471654
# 2397 2021-04-14  63109.695312  ...  3.559282e+10   8215124752
# 2398 2021-04-15  63314.011719  ...  3.232561e+10   6470712244
# 2399 2021-04-16  61572.789062  ...  3.619693e+10  11850832933
#
# [2400 rows x 19 columns]

# %% [markdown]
# **MINI CHALLENGE #3 SOLUTION:**
# - **Add Litecoin (LTC) to the list and plot similar kind of graph showing all three currencies**

# %%
investments_df.plot(x = 'Date', y = [ 'BTC-USD Price', 'ETH-USD Price', 'LTC-USD Price'], linewidth = 2, figsize = (14,6))
plt.ylabel('Price')
plt.title('Crypto Prices')
plt.grid()

# %% [markdown]
# **MINI CHALLENGE #4 SOLUTION:**
# - **Try to set subplots = False and examine the output.**
# - **Try to set sharey to True and examine the output. What do you infer?**

# %%
investments_df.plot(x = 'Date', title = 'Crypto Prices', subplots = False, grid = True, figsize = (14, 6));

# %% [markdown]
# **MINI CHALLENGE #5 SOLUTION:**
# - **Plot the daily returns of BTC vs. LTC**

# %%
# Plot Daily returns of BTC vs. ETH
daily_return_df.plot.scatter('BTC', 'LTC', figsize = (12, 7))

# %% [markdown]
# **MINI CHALLENGE #6 SOLUTION:**
# - **Assume that you became bullish on XRP and decided to allocate 60% of your assets in it. You also decided to equally divide the rest of your assets in other coins (BTC, LTC, ADA, and ETH). Change the allocations and plot the pie chart.**
# - **Use 'explode' to increase the separation between BTC and the rest of the portfolio (External Research is Required)**

# %%
my_dict =  {'allocation %': [10, 10, 10, 60, 10]}
explode = (0, 0, 0, 0.2, 0)

crypto_df = pd.DataFrame(data = my_dict, index = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])
crypto_df.plot.pie(y = 'allocation %', explode = explode, figsize = (8, 8))

plt.title('CRYPTO PORTFOLIO PIE CHART')
# Out:
# Text(0.5, 1.0, 'CRYPTO PORTFOLIO PIE CHART')

# %% [markdown]
# **MINI CHALLENGE #7 SOLUTION:**
# - **Plot the histogram for ETH returns using 30 bins with red color**

# %%
mu = daily_return_df['ETH'].mean() # mean of distribution
sigma = daily_return_df['ETH'].std() # standard deviation of distribution

num_bins = 40

# Plot the histogram of the returns
plt.figure(figsize = (20, 15))

daily_return_df['ETH'].plot.hist(bins = 30, alpha = 0.5, facecolor = 'r', figsize = (12, 6))

plt.grid()
plt.ylabel('Probability')
plt.title('Histogram: mu=' + str(mu) + ', sigma=' +str(sigma));

# %% [markdown]
# **FINAL BREAKOUT ROOM CHALLENGE:**
# - **Import stock_daily_prices.csv data that's included in the course/workshop package**
# - **On one graph, plot the following 3 stocks only: AAPL, sp500 and GOOG**
# - **Add legends indicating S&P500, AAPL and GOOG**
# - **Place the legend in the "upper center" location**
# - **Plot subplots containing prices of AAPL, sp500 and GOOG**

# %%
stocks_df = pd.read_csv('stock_daily_prices.csv')
stocks_df
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     2012-01-12   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     2012-01-13   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     2012-01-17   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     2012-01-18   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     2012-01-19   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  2020-08-05  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  2020-08-06  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  2020-08-07  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  2020-08-10  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# ...

# %%
stocks_df.plot(x = 'Date', y = ['AAPL', 'sp500', 'GOOG'], linewidth = 3, figsize = (12, 8))
plt.ylabel('Price')
plt.title('Stock Prices')
plt.legend(loc = "upper center")
plt.grid()

# %%
stocks_df.plot(x = 'Date', y = ['AAPL', 'sp500', 'GOOG'], subplots = True, grid = True, linewidth = 3, figsize = (12, 8))
plt.ylabel('Price')
plt.title('Stock Prices')
plt.legend(loc = "upper center")
