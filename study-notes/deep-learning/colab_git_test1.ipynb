# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/DL_study1
# Out:
# /content/drive/MyDrive/DL_study1

# %%
# !git config --global user.email 'https://github.com/jinyoung0711'
# !git config --global user.name 'jinyoung0711'

# %%
# !git add colab_git_test1.ipynb
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
print('Hello')
# Out:
# Hello
